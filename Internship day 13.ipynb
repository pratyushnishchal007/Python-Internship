# %%
class CoffeeMaker:
    milk=1000
    water=1500
    coffee=2000
    money=0
    def __init__(self,value):
        self.value=value
    def report(self,value):
        print("Water:",self.water,"\nMilk:",self.milk,"\nCoffee:",self.coffee,"\nMoney:$",self.money)
    def Makecoffee(self,value):
        if(value=="1"):
            self.water=self.water-30
            self.milk=self.milk-50
            self.coffee=self.coffee-80
            self.money=self.money+2.50
            print("Here is your latte. Enjoy!")
        elif(value=="2"):
            self.water=self.water-45
            self.milk=self.milk-60
            self.coffee=self.coffee-90
            self.money=self.money+3.50
            print("Here is your espresso. Enjoy!")
        elif(value=="3"):
            self.water=self.water-50
            self.milk=self.milk-70
            self.coffee=self.coffee-100
            self.money=self.money+4.50
            print("Here is your cappucino. Enjoy!")
    def transaction(self,value,price):
        if(value=="latte"):
            if(price<2.50):
                print("Sorry that's not enough money. Money refunded.")
            elif(price>2.50):
                print("Here is $",price-2.50,"dollars in change.")
                self.Makecoffee(value)
            else:
                self.Makecoffee(value)
        elif(value=="espresso"):
            if(price<3.50):
                print("Sorry that's not enough money. Money refunded.")
            elif(price>3.50):
          print("Here is $",price-3.50,"dollars in change.")
        self.Makecoffee(value)
            else:
               self.Makecoffee(value)
        else:
            if(price<4.50):
                print("Sorry that's not enough money. Money refunded.")
            elif(price>4.50):
                print("Here is $",price-4.50,"dollars in change.")
                self.Makecoffee(value)
            else:
                self.Makecoffee(value)
    def coins(self,value):
        quarters=0.30
        dimes=0.20
        pennies=0.05
        nickles=0.15
        print("Insert coins!")
        a=int(input("Enter number of dimes:"))
        b=int(input("Enter number of nickles:"))
        c=int(input("Enter number of quarters:"))
        d=int(input("Enter number of pennies:"))
        price=(a*dimes)+(b*nickles)+(c*quarters)+(d*pennies)
        self.transaction(value,price)
    def res(self,value):
        if(value=="1"):
            if(self.water<30):
                print("Sorry there is not enough water!")
            elif(self.milk<50):
                print("Sorry there is not enough milk!")
            elif(self.coffee<80):
                print("Sorry there is not enough coffee!")
            else:
                self.coins(value)
        elif(value=="2"):
            if(self.water<45):
                print("Sorry there is not enough water!")
            elif(self.milk<60):
                print("Sorry there is not enough milk!")
            elif(self.coffee<90):
                print("Sorry there is not enough coffee!")
            else:
                self.coins(value)
        elif(value=="3"):
            if(self.water<50):
                print("Sorry there is not enough water!")
            elif(self.milk<70):
                print("Sorry there is not enough milk!")
            elif(self.coffee<100):
                print("Sorry there is not enough coffee!")
            else:
                self.coins(value)  
x="on"
s=CoffeeMaker(x)
while(True):
    print("\n\nLatte:$2.50\nEspresso:$3.50\nCappucino:$4.50")
    x=input("What would you like?(espresso/latte/cappucino):")
    if(x=="off"):
        break
    if(x=="report"):
        s.report(x)
        continue
    s.res(x)
# Out:
#   File "<tokenize>", line 42
#     print("Here is $",price-3.50,"dollars in change.")
#     ^
# IndentationError: unindent does not match any outer indentation level
